# %%
import os
import sys
from pyspark.sql import SparkSession
from pyspark.sql.types import * # Import all types

# Point the executor to the same Python interpreter the driver is using
os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable
from pyspark.sql.functions import input_file_name

from pyspark.sql.types import StructType, StructField, StringType, DoubleType, IntegerType




spark = SparkSession.builder \
    .appName("StreamingWeather") \
    .master("local[*]") \
    .getOrCreate()

schema = StructType([
    StructField("STATION", StringType(), True),
    StructField("DATE", StringType(), True),
    StructField("LATITUDE", DoubleType(), True),
    StructField("LONGITUDE", DoubleType(), True),
    StructField("ELEVATION", DoubleType(), True),
    StructField("NAME", StringType(), True),
    StructField("TEMP", DoubleType(), True),
    StructField("TEMP_ATTRIBUTES", StringType(), True),
    StructField("DEWP", DoubleType(), True),
    StructField("DEWP_ATTRIBUTES", StringType(), True),
    StructField("SLP", DoubleType(), True),
    StructField("SLP_ATTRIBUTES", StringType(), True),
    StructField("STP", DoubleType(), True),
    StructField("STP_ATTRIBUTES", StringType(), True),
    StructField("VISIB", DoubleType(), True),
    StructField("VISIB_ATTRIBUTES", StringType(), True),
    StructField("WDSP", DoubleType(), True),
    StructField("WDSP_ATTRIBUTES", StringType(), True),
    StructField("MXSPD", DoubleType(), True),
    StructField("GUST", DoubleType(), True),
    StructField("MAX", DoubleType(), True),
    StructField("MAX_ATTRIBUTES", StringType(), True),
    StructField("MIN", DoubleType(), True),
    StructField("MIN_ATTRIBUTES", StringType(), True),
    StructField("PRCP", DoubleType(), True),
    StructField("PRCP_ATTRIBUTES", StringType(), True),
    StructField("SNDP", DoubleType(), True),
    StructField("FRSHTT", IntegerType(), True)
])

# Read the stream using the glob path
df_stream = spark.readStream \
    .schema(schema) \
    .option("header", True) \
    .option("pathGlobFilter", "*.csv") \
    .csv("hdfs://localhost:9000/streaming_weather/*")

# --- 2. Define Alerting Logic ---
alerts_df = df_stream.filter(
    (df_stream["TEMP"] > 95.0) |
    (df_stream["GUST"] > 30.0) |
    (df_stream["PRCP"] > 0.5)
)

# --- 3. Create a Function to Process and Print Alerts ---
def process_alerts(batch_df, epoch_id):
    # Check if the batch DataFrame is empty. batch_df will only have data that matches our filter.
    if batch_df.count() > 0:
        print(f"--- Batch {epoch_id}: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---")
        
        # Collect the alerts and print the details
        alerts_to_send = batch_df.select("NAME", "DATE", "TEMP", "GUST", "PRCP").collect()
        for alert in alerts_to_send:
            print(f"  -> ALERT at {alert['NAME']} on {alert['DATE']}: Temp={alert['TEMP']}°F, Gust={alert['GUST']}mph, Rain={alert['PRCP']}in")
    else:
        # This will print for any batch that has no alerts
        print(f"--- Batch {epoch_id}: No alerts. Conditions normal. ---")

# --- 4. Start the Streaming Query ---
query = alerts_df.writeStream \
    .foreachBatch(process_alerts) \
    .outputMode("append") \
    .start()

query.awaitTermination()
# Out:
# --- Batch 0: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-03: Temp=64.0°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-06: Temp=68.0°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-01: Temp=62.6°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-05: Temp=65.4°F, Gust=999.9mph, Rain=0.0in
# --- Batch 1: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-07: Temp=63.7°F, Gust=68.0mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-08: Temp=62.8°F, Gust=40.0mph, Rain=0.0in
# --- Batch 2: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-11: Temp=63.6°F, Gust=42.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-12: Temp=62.9°F, Gust=40.0mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-13: Temp=59.2°F, Gust=49.9mph, Rain=0.0in
# --- Batch 3: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-15: Temp=63.4°F, Gust=45.1mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-18: Temp=55.2°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-19: Temp=55.1°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-20: Temp=58.8°F, Gust=45.1mph, Rain=0.0in
# --- Batch 4: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-23: Temp=72.8°F, Gust=46.0mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-24: Temp=65.6°F, Gust=40.0mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-22: Temp=67.3°F, Gust=32.1mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-25: Temp=55.0°F, Gust=32.1mph, Rain=0.0in
# --- Batch 5: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-30: Temp=53.5°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-29: Temp=53.4°F, Gust=999.9mph, Rain=0.0in
# --- Batch 6: No alerts. Conditions normal. ---
# --- Batch 7: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-06: Temp=57.4°F, Gust=999.9mph, Rain=99.99in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-08: Temp=57.7°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-02: Temp=65.7°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-01: Temp=62.6°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-03: Temp=67.5°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-01-31: Temp=55.5°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-05: Temp=55.2°F, Gust=999.9mph, Rain=0.0in
# --- Batch 8: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-11: Temp=55.6°F, Gust=999.9mph, Rain=0.0in
# --- Batch 9: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-14: Temp=54.8°F, Gust=29.9mph, Rain=99.99in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-19: Temp=68.0°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-15: Temp=60.0°F, Gust=35.0mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-16: Temp=64.4°F, Gust=999.9mph, Rain=0.0in
# --- Batch 10: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-20: Temp=70.0°F, Gust=40.0mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-23: Temp=72.9°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-24: Temp=72.0°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-22: Temp=72.1°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-25: Temp=76.5°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-26: Temp=74.8°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-02-21: Temp=71.4°F, Gust=999.9mph, Rain=0.0in
# --- Batch 11: No alerts. Conditions normal. ---
# --- Batch 12: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-03-05: Temp=54.1°F, Gust=999.9mph, Rain=99.99in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-03-06: Temp=50.2°F, Gust=21.0mph, Rain=99.99in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-03-03: Temp=57.0°F, Gust=35.0mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-03-04: Temp=59.8°F, Gust=32.1mph, Rain=0.0in
# --- Batch 13: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-03-11: Temp=55.9°F, Gust=28.0mph, Rain=99.99in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-03-08: Temp=59.5°F, Gust=34.0mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-03-07: Temp=54.8°F, Gust=40.0mph, Rain=0.0in
# --- Batch 14: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-03-14: Temp=47.0°F, Gust=35.0mph, Rain=99.99in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-03-17: Temp=60.5°F, Gust=24.1mph, Rain=99.99in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-03-18: Temp=59.9°F, Gust=40.0mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-03-15: Temp=57.4°F, Gust=38.1mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-03-13: Temp=52.7°F, Gust=35.0mph, Rain=0.0in
# --- Batch 15: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-03-21: Temp=69.5°F, Gust=999.9mph, Rain=0.0in
# --- Batch 16: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-03-26: Temp=58.7°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-03-27: Temp=59.2°F, Gust=999.9mph, Rain=0.0in
# --- Batch 17: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-04-02: Temp=58.4°F, Gust=38.1mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-04-04: Temp=66.2°F, Gust=33.0mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-04-01: Temp=59.1°F, Gust=35.0mph, Rain=0.0in
# --- Batch 18: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-04-05: Temp=73.4°F, Gust=41.0mph, Rain=0.0in
# --- Batch 19: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-04-16: Temp=62.0°F, Gust=999.9mph, Rain=0.0in
# --- Batch 20: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-04-23: Temp=60.2°F, Gust=999.9mph, Rain=0.0in
# --- Batch 21: No alerts. Conditions normal. ---
# --- Batch 22: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-05-07: Temp=65.7°F, Gust=999.9mph, Rain=0.0in
# --- Batch 23: No alerts. Conditions normal. ---
# --- Batch 24: No alerts. Conditions normal. ---
# --- Batch 25: No alerts. Conditions normal. ---
# --- Batch 26: No alerts. Conditions normal. ---
# --- Batch 27: No alerts. Conditions normal. ---
# --- Batch 28: No alerts. Conditions normal. ---
# --- Batch 29: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-06-18: Temp=85.2°F, Gust=999.9mph, Rain=0.0in
# --- Batch 30: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-06-25: Temp=71.9°F, Gust=999.9mph, Rain=0.0in
# --- Batch 31: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-07-07: Temp=77.8°F, Gust=999.9mph, Rain=0.0in
# --- Batch 32: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-07-12: Temp=75.0°F, Gust=999.9mph, Rain=0.0in
# --- Batch 33: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-07-18: Temp=79.3°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-07-19: Temp=77.3°F, Gust=999.9mph, Rain=0.0in
# --- Batch 34: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-07-21: Temp=70.4°F, Gust=999.9mph, Rain=0.0in
# --- Batch 35: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-07-26: Temp=71.2°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-07-23: Temp=72.2°F, Gust=999.9mph, Rain=0.0in
# --- Batch 36: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-08-08: Temp=88.7°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-07-30: Temp=80.0°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-08-01: Temp=77.9°F, Gust=999.9mph, Rain=0.0in
# --- Batch 37: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-08-11: Temp=83.5°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-08-10: Temp=82.7°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-08-17: Temp=75.7°F, Gust=999.9mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-08-13: Temp=78.1°F, Gust=999.9mph, Rain=0.0in
# --- Batch 38: 🚨 SEVERE WEATHER ALERTS DETECTED! 🚨 ---
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-08-22: Temp=95.2°F, Gust=25.1mph, Rain=0.0in
#   -> ALERT at LOS ANGELES WHITEMAN AIRPORT, CA US on 2025-08-20: Temp=87.7°F, Gust=999.9mph, Rain=0.0in

# %%
# In a new cell

# You can run this cell over and over to see the latest data!
spark.sql("SELECT * FROM live_weather_updates").show(truncate=False)
